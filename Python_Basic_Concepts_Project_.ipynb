# %% [markdown]
# # Patient information
# Punyatoya Behera

# %% [markdown]
# ## This is a mini project on the basic concepts of Python.

# %%
first_name = "Albert"  # first name of the patient
last_name = "Cho" #  last name of the patient
age = 45  # age of the patient
sex = "M"  #  sex of the patient at birth
ht = 6.3  #  height of the patient in feet
wt = 181.39  #  weight of the patient in pounds
smoker = False #  smoker status of the patient


# calculating BMI

ht_in = ht * 12 # height in inches
bmi = round((703 * wt / (ht_in ** 2)),2)
print(f'{first_name} {last_name}, you have a Body Mass Index of {bmi}.')

# calculating dosage

wt_kg = wt*0.45
dsg =round(10*wt_kg)
dsg_freq = 8 # number of hours per dosage
tot_days = 10 # total number of days
tot_dsg_count = 24*tot_days/dsg_freq # total number of dosages
tot_dsg = tot_dsg_count * dsg # total dosage in mg
print(f'Provide {first_name} {last_name} with {tot_dsg_count} doses of {dsg} mg of amoxicillin, or {tot_dsg} total mg.')
# Out:
# Albert Cho, you have a Body Mass Index of 22.31.
# Provide Albert Cho with 30.0 doses of 816 mg of amoxicillin, or 24480.0 total mg.
